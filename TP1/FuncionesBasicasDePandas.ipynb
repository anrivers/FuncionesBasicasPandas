# %% [markdown]
# <a href="https://colab.research.google.com/github/anrivers/FuncionesBasicasPandas/blob/main/TP1/FuncionesBasicasDePandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Funciones basicas en pandas
#Importar la liberia de pandas
import pandas as pd
#Leer el archvio csv
df=pd.read_csv('brands.csv')
#Llamar a la variable df
df
# Out:
#            name                               site  \
# 0          Nike               https://www.nike.com
# 1        Adidas             https://www.adidas.com
# 2      Skechers           https://www.skechers.com
# 3   New Balance         https://www.newbalance.com
# 4         ASICS     https://www.asics.com/us/en-us
# 5          Puma          https://us.puma.com/us/en
# 6  Under Armour  https://www.underarmour.com/en-us
# 7          Fila               https://www.fila.com
# 8      Columbia  https://www.columbia.com/footwear
# 9       K-Swiss                 https://kswiss.com
#
#                                            wikipedia  wikipedia_languages_num  \
# 0         https://en.wikipedia.org/wiki/Nike%2C_Inc.                       75
# 1               https://en.wikipedia.org/wiki/Adidas                       91
# 2             https://en.wikipedia.org/wiki/Skechers                       17
# 3          https://en.wikipedia.org/wiki/New_Balance                       32
# ...

# %%
#obtener información resumida, incluyendo detalles sobre las columnas, el tipo de datos, la cantidad de valores no nulos y el uso de memoria
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          10 non-null     object
#  1   site                          10 non-null     object
#  2   wikipedia                     10 non-null     object
#  3   wikipedia_languages_num       10 non-null     int64
#  4   twitter                       10 non-null     object
#  5   facebook                      10 non-null     object
#  6   facebook_likes                10 non-null     object
#  7   facebook_followers            10 non-null     object
#  8   facebook_verified             10 non-null     object
#  9   instagram                     10 non-null     object
#  10  youtube                       10 non-null     object
#  11  youtube_subscribers           10 non-null     object
# ...

# %%
#Muestra los primeros 5 registros
df.head()
# Out:
#           name                            site  \
# 0         Nike            https://www.nike.com
# 1       Adidas          https://www.adidas.com
# 2     Skechers        https://www.skechers.com
# 3  New Balance      https://www.newbalance.com
# 4        ASICS  https://www.asics.com/us/en-us
#
#                                     wikipedia  wikipedia_languages_num  \
# 0  https://en.wikipedia.org/wiki/Nike%2C_Inc.                       75
# 1        https://en.wikipedia.org/wiki/Adidas                       91
# 2      https://en.wikipedia.org/wiki/Skechers                       17
# 3   https://en.wikipedia.org/wiki/New_Balance                       32
# 4         https://en.wikipedia.org/wiki/Asics                       35
#
#          twitter     facebook facebook_likes facebook_followers  \
# 0          /Nike        /nike       36842713           38667225
# 1        /adidas      /adidas       41046633           41755214
# ...

# %%
#Muestra los ultimos 5 registros
df.tail()
# Out:
#            name                               site  \
# 5          Puma          https://us.puma.com/us/en
# 6  Under Armour  https://www.underarmour.com/en-us
# 7          Fila               https://www.fila.com
# 8      Columbia  https://www.columbia.com/footwear
# 9       K-Swiss                 https://kswiss.com
#
#                                            wikipedia  wikipedia_languages_num  \
# 5         https://en.wikipedia.org/wiki/Puma_(brand)                       60
# 6         https://en.wikipedia.org/wiki/Under_Armour                       32
# 7                 https://en.wikipedia.org/wiki/Fila                       35
# 8  https://en.wikipedia.org/wiki/Columbia_Sportswear                       14
# 9              https://en.wikipedia.org/wiki/K-Swiss                       12
#
#          twitter             facebook facebook_likes facebook_followers  \
# 5          /puma                /puma            21M                  x
# ...

# %%
#Mestra los primeros 8 registros
df.head(8)
# Out:
#            name                               site  \
# 0          Nike               https://www.nike.com
# 1        Adidas             https://www.adidas.com
# 2      Skechers           https://www.skechers.com
# 3   New Balance         https://www.newbalance.com
# 4         ASICS     https://www.asics.com/us/en-us
# 5          Puma          https://us.puma.com/us/en
# 6  Under Armour  https://www.underarmour.com/en-us
# 7          Fila               https://www.fila.com
#
#                                     wikipedia  wikipedia_languages_num  \
# 0  https://en.wikipedia.org/wiki/Nike%2C_Inc.                       75
# 1        https://en.wikipedia.org/wiki/Adidas                       91
# 2      https://en.wikipedia.org/wiki/Skechers                       17
# 3   https://en.wikipedia.org/wiki/New_Balance                       32
# 4         https://en.wikipedia.org/wiki/Asics                       35
# 5  https://en.wikipedia.org/wiki/Puma_(brand)                       60
# ...

# %%
#Mestra los ultimos 8 registros
df.tail(8)
# Out:
#            name                               site  \
# 2      Skechers           https://www.skechers.com
# 3   New Balance         https://www.newbalance.com
# 4         ASICS     https://www.asics.com/us/en-us
# 5          Puma          https://us.puma.com/us/en
# 6  Under Armour  https://www.underarmour.com/en-us
# 7          Fila               https://www.fila.com
# 8      Columbia  https://www.columbia.com/footwear
# 9       K-Swiss                 https://kswiss.com
#
#                                            wikipedia  wikipedia_languages_num  \
# 2             https://en.wikipedia.org/wiki/Skechers                       17
# 3          https://en.wikipedia.org/wiki/New_Balance                       32
# 4                https://en.wikipedia.org/wiki/Asics                       35
# 5         https://en.wikipedia.org/wiki/Puma_(brand)                       60
# 6         https://en.wikipedia.org/wiki/Under_Armour                       32
# ...

# %%
#Se utiliza para obtener estadísticas descriptivas de las columnas numéricas
df.describe()
# Out:
#        wikipedia_languages_num  youtube_videos  youtube_views  \
# count                10.000000       10.000000   1.000000e+01
# mean                 40.300000      421.000000   1.706006e+08
# std                  26.650203      295.202379   1.593649e+08
# min                  12.000000       18.000000   2.385200e+04
# 25%                  20.750000      187.500000   1.768645e+07
# 50%                  33.500000      368.000000   1.555485e+08
# 75%                  53.750000      628.500000   2.960945e+08
# max                  91.000000      893.000000   4.021620e+08
#
#        pagespeedweb_performance_m  pagespeedweb_accessibility_m  \
# count                    10.00000                     10.000000
# mean                     32.90000                     87.400000
# std                       9.58529                      9.663218
# min                      16.00000                     67.000000
# 25%                      28.00000                     84.000000
# ...

# %%
#Se utiliza en pandas para encontrar el valor máximo en la columna 'wikipedia_languages_num'
df['wikipedia_languages_num'].max()
# Out:
# 91

# %%
#Se utiliza en pandas para encontrar el valor minimo en la columna 'wikipedia_languages_num'
df['wikipedia_languages_num'].min()
# Out:
# 12

# %%
 #Se utiliza en pandas para obtener un array o lista de todos los valores únicos
df['wikipedia_languages_num'].unique()
# Out:
# array([75, 91, 17, 32, 35, 60, 14, 12])

# %%
#Ordena los valores
df.sort_values('wikipedia_languages_num',ascending=False)
# Out:
#            name                               site  \
# 1        Adidas             https://www.adidas.com
# 0          Nike               https://www.nike.com
# 5          Puma          https://us.puma.com/us/en
# 4         ASICS     https://www.asics.com/us/en-us
# 7          Fila               https://www.fila.com
# 3   New Balance         https://www.newbalance.com
# 6  Under Armour  https://www.underarmour.com/en-us
# 2      Skechers           https://www.skechers.com
# 8      Columbia  https://www.columbia.com/footwear
# 9       K-Swiss                 https://kswiss.com
#
#                                            wikipedia  wikipedia_languages_num  \
# 1               https://en.wikipedia.org/wiki/Adidas                       91
# 0         https://en.wikipedia.org/wiki/Nike%2C_Inc.                       75
# 5         https://en.wikipedia.org/wiki/Puma_(brand)                       60
# 4                https://en.wikipedia.org/wiki/Asics                       35
# ...
